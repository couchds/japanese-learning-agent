# %% [markdown]
# # Explore Training Data
#
# This notebook explores the exported pronunciation recordings and prepares them for model training.

# %%
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import IPython.display as ipd

# %% [markdown]
# ## Load Manifest

# %%
manifest_path = Path('../data/training/manifest.csv')

if not manifest_path.exists():
    print("Manifest not found. Run: python scripts/export_training_data.py")
else:
    df = pd.read_csv(manifest_path)
    print(f"Loaded {len(df)} recordings")
    display(df.head())
